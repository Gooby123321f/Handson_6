# %% [markdown]
# # Dictionaries
#
# To submit this assignment in D2l, post the link to your notebook file on your GitHub account.

# %% [markdown]
# ## 12.1 Champion Counter
# Create a program that reads a text file that contains a list of FIFA World Cup champions and determines the country that has won the most championships.
#
# ### Console:
# ```powershell
# Country	        Wins	Years
# =======	        ====	=====
# Argentina       2       1978, 1986
# Brazil	        5       1958, 1962, 1970, 1994, 2002
# England	        1       1966
# France	        1       1998
# Germany	        4       1954, 1974, 1990, 2014
# Italy	        4       1934, 1938, 1982, 2006
# Spain	        1       2010
# Uruguay	        2       1930, 1950
# ```
#
# ### Specifications:
# - Use the attached text file named `world_cup_champions.txt` that contains data like this:
# ```powershell
# Year,Country,Coach,Captain
# 1930,Uruguay,Alberto Suppici,José Nasazzi
# 1934,Italy,Vittorio Pozzo,Gianpiero Combi
# 1938,Italy,Vittorio Pozzo,Giuseppe Meazza
# ...
# ```
# - When the program starts, it should read the text file and use a dictionary to store the required data using the name of each country that has won the World Cup as the key.
# - The program should compile the data shown above and display the countries alphabetically.

# %%
games = {}


with open("world_cup_champions.txt", "r") as f:
    f.readline()
    for line in f:
        gameArray = line.split(",")
        key = gameArray[1]
        games[key] = []

with open("world_cup_champions.txt", "r") as g:
    g.readline()
    for line in g:
        gameArray = line.split(",")
        for key in games:
            if(key == gameArray[1]):
                games[key].append(gameArray[0])
                break

sortedCountries = []
for key in games:
    sortedCountries.append(key)
sortedCountries.sort()

print("Country\t\tWins\tYears\n=======\t\t====\t=====")
for elem in sortedCountries:
    if(len(elem) >= 8):
        print(elem + "\t" + str(len(games[elem])) + "\t", end = "")
    else:
        print(elem + "\t\t" + str(len(games[elem])) + "\t", end = "")
    for elem2 in games[elem]:
        if(elem2 == games[elem][len(games[elem]) - 1]):
            print(elem2, end = "")
            break
        print(elem2 + ", ", end = "")
    print("\n")


if(1 == 0):
    """"
    method that creates the dictionary by reading lines from the program
    with open("world_cup_champions.txt", "r") as f:
        f.readline()
        for line in f:
            gameArray = line.split(",")
            key = gameArray[0]
            gameArray.pop(0)
            games[key] = gameArray
    
    sortedCountries = []
    countryKeys = []
    ##sorts the countries in alphabetical order and stores the country keys for data printing later in the program
    for key in games:
        countryKeys.append(key)
        if not(games[key][0] in sortedCountries):
            sortedCountries.append(games[key][0])
    sortedCountries.sort()
    
    ##sets up printing the data
    print("Country\t\tWins\tYears\n=======\t\t====\t=====")
    ##adds up every win a country has, and stores all of the years that they won in the array
    for i in range(0, len(sortedCountries), 1):
        yearArray = []
        wins = 0
        for key in games:
            if(games[key][0] == sortedCountries[i]):
                wins += 1
                yearArray.append(key)
    
        ##prints the data of the country's superbowl wins
        ##if statement to keep the tabbing look good, not necessary but looks better
        if(len(sortedCountries[i]) >= 8):
            print(sortedCountries[i] + "\t" + str(wins) + "\t", end = "")
        else:
            print(sortedCountries[i] + "\t\t" + str(wins) + "\t", end = "")
        for i in range(0, len(yearArray), 1):
            print(str(yearArray[i]), end = "")
            if not(i == len(yearArray) - 1):
                print(", ", end = "")
        print("")
    """
# Out:
# Country		Wins	Years
# =======		====	=====
# Argentina	2	1978, 1986
#
# Brazil		5	1958, 1962, 1970, 1994, 2002
#
# England		1	1966
#
# France		1	1998
#
# Germany		4	1954, 1974, 1990, 2014
#
# Italy		4	1934, 1938, 1982, 2006
#
# Spain		1	2010
#
# Uruguay		2	1930, 1950

# %% [markdown]
# ## 12.2 Monthly Sales
# Create a program that allows you to view and edit the sales amounts for each month of the current year.
#
# ### Console:
# ```powershell
# Monthly Sales program
#
# COMMAND MENU
# view	- View sales for specified month
# edit	- Edit sales for specified month
# totals - View sales summary for year
# exit	- Exit program
#
# Command: view
# Three-letter Month: jan
# Sales amount for Jan is 14,317.00.
#
# Command: edit
# Three-letter Month: jan
# Sales Amount: 15293
# Sales amount for Jan is 15,293.00.
#
# Command: totals
# Yearly total: 67,855.00
# Monthly average: 5,654.58
#
# Command: view
# Three-letter Month: july
# Invalid three-letter month.
#
# Command: exit Bye!
# ```
#
# ### Specifications:
# - Use the attached text file named `monthly_sales.txt` that consists of rows that contain three-letter abbreviations for the month and the monthly sales.
# - The program should read the file and store the sales data for each month in a dictionary with the month abbreviation as the key for each item.
# - Whenever the sales data is edited, the program should write the changed data to the text file.

# %%
def displayMenu():
    print("COMMAND MENU\nview - View sales for specified month\nedit - Edit sales for specified month"
    "\ntotal - View sales summary for whole year\nexit - Exit program\n")
    
def view(dictionary, monthsArr):
    month = input("Three-Letter Month: ")
    boolean = True
    while(boolean):
        for i in range(0, len(monthsArr), 1):                
            if(month.lower() == monthsArr[i].lower()):
                boolean = False
                break
            elif(i == len(monthsArr)-1 and not month.lower() == monthsArr[i].lower()):
                month = input("Invalid month input! enter a valid 3 letter abbreviation for a month: ")
                i = 0
        
    print("Sales amount for " + month.capitalize() + ": " + str(round(dictionary[month.capitalize()], 2)))

def edit(dictionary, monthsArr):
    month = input("Three-Letter Month: ")
    boolean = True
    while(boolean):
        for i in range(0, len(monthsArr), 1):                
            if(month.lower() == monthsArr[i].lower()):
                boolean = False
                break
            elif(i == len(monthsArr)-1 and not month.lower() == monthsArr[i].lower()):
                month = input("Invalid month input! enter a valid 3 letter abbreviation for a month: ")
                i = 0
        
    newMoney = float(input("Sales Amount: "))
    dictionary[month.capitalize()] = newMoney
    print("Sales amount for " + month.capitalize() + " is " + str(newMoney))
    
    with open("monthly_sales.txt", "w") as f:
        for key in dictionary:
            f.write(key + "\t" + str(dictionary[key]) + "\n")

def total(dictionary):
    totalMoney = 0.0
    for key in dictionary:
        totalMoney += dictionary[key]
    print("Yearly Total: " + str(round(totalMoney, 2)))
    print("Monthly Average: " + str(round(totalMoney / 12, 2)))
        
    
def main():
    ##declares an array of months for validation and the sales dictionary
    monthArray = []
    sales = {}
    with open("monthly_sales.txt", "r") as f:
        for line in f:
            temp = line.split("\t")
            monthArray.append(temp[0])
            sales[temp[0]] = float(temp[1].replace("\n", ""))
            
    displayMenu()
    while(True):
        command = input("Command: ")
        while not(command == "view" or command == "edit" or command == "total" or command == "exit"):
            command = input("\nInvalid input! Enter a command from the list above: ")
        if(command == "exit"):
            break
        elif(command == "view"):
            view(sales, monthArray)
        elif(command == "edit"):
            edit(sales, monthArray)
        else:
            total(sales)
        print("\n")
    print("Bye!")
            
if __name__ == "__main__":
    main()
# Out:
# COMMAND MENU
# view - View sales for specified month
# edit - Edit sales for specified month
# total - View sales summary for whole year
# exit - Exit program
# Command:  view
# Three-Letter Month:  jan
# Sales amount for Jan: 123456.0
# Command:  view
# Three-Letter Month:  e
# Invalid month input! enter a valid 3 letter abbreviation for a month:  r
# Invalid month input! enter a valid 3 letter abbreviation for a month:
# Invalid month input! enter a valid 3 letter abbreviation for a month:  t
# Invalid month input! enter a valid 3 letter abbreviation for a month:  y
# Invalid month input! enter a valid 3 letter abbreviation for a month:  ui
# Invalid month input! enter a valid 3 letter abbreviation for a month:  mar
# Sales amount for Mar: 1073.0
# Command:  exit
# Bye!
